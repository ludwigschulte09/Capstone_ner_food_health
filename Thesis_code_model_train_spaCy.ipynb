# %%
#this code was run in colab, so the drive needs to be mounted
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
#change directory
os.chdir('/content/drive/MyDrive/capstone')

# %%
import pandas as pd

# %%
# !pip install spacy-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.5/193.5 KB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 95.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 112.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.2 MB/s eta 0:00:00
# ...

# %%
#train a model using the spaCy pipeline. the config2.cfg file corresponds to the default spaCy configuration
# !python -m spacy train config2.cfg --verbose --output ner_food_health  --paths.train train.spacy --paths.dev valid.spacy  --gpu-id 0
# Out:
# [2023-01-30 19:59:18,939] [DEBUG] Config overrides from CLI: ['paths.train', 'paths.dev']
# DEBUG:spacy:Config overrides from CLI: ['paths.train', 'paths.dev']
# ℹ Saving to output directory: ner_food_health
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2023-01-30 19:59:23,479] [INFO] Set up nlp object from config
# INFO:spacy:Set up nlp object from config
# [2023-01-30 19:59:23,488] [DEBUG] Loading corpus from path: valid.spacy
# DEBUG:spacy:Loading corpus from path: valid.spacy
# [2023-01-30 19:59:23,489] [DEBUG] Loading corpus from path: train.spacy
# DEBUG:spacy:Loading corpus from path: train.spacy
# [2023-01-30 19:59:23,489] [INFO] Pipeline: ['transformer', 'ner']
# INFO:spacy:Pipeline: ['transformer', 'ner']
# [2023-01-30 19:59:23,492] [INFO] Created vocabulary
# INFO:spacy:Created vocabulary
# [2023-01-30 19:59:23,493] [INFO] Finished initializing nlp object
# INFO:spacy:Finished initializing nlp object
# ...
